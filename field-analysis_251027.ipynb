# %%
# log파일 추가 시 한번만 실행
import _common
_common.read_logs()
# Out:
# Reading logs/Huam415-1/251016_SM-S938N_TEST06_n-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST16-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST31_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST24-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST17-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST02_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST09_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST30_-M2_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST02_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST13_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST13-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST20-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST14_-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST05_n-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST21-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST12-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST11-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST22-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST03_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST04_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST10_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST23-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST18-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST19-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST33_-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST01_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST01_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST34-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST14-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST35_-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST03_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST32_-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST04_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST15-M2_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST01_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST13_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST14_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST13-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST20-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST05_n-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST21-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST12-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST30_-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST04_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST03_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST09_-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST04_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST03_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST16-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST06_n-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST31_-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST01_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST24-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST17-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST34-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST14-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST35_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST32_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST15-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST02_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST18-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST33_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST19-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST02_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST11-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST22-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST10_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST23-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST10_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST11_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST17_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST08_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST16_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST09_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST18_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST14_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST15_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST12_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST06_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST07_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST13_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST14_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST12_M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST13_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST08_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST16_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST09_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST18_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST14_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST17_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST10_M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST11_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST12_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST13_M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST06_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST07_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST13_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST14_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST15_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST12_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST27_STATIC_-M1_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST26_STATIC_-M1_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST25_STATIC_-M1_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST25_STATIC_-M2_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST27_STATIC_-M2_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST26_STATIC_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST24_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST23_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST28_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST38_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST11_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST26_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST21_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST19_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST02-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST04_M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST42_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST17_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST10_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST40_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST03-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST05_M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST29_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST20_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST07-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST39_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST27_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST10_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST33-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST22_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST25_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST32_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST06-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST18_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST11_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST16_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST43_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST12_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST15_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST40_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST09_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST10-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST31_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST36_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST28_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST05-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST21_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST03_M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST26_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST38_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST04-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST23_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST24_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST17_TRACE_-M2_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST02_M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST16_-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST34-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST41_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST14_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST13_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST35-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST01-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST25_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST22_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST09-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST37_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST29_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST30_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST27_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST08-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST39_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST20_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST09_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST18_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST11_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST16_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST43_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST29_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST20_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST07-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST33-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST39_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST10_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST27_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST22_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST25_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST32_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST06-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST19_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST02-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST42_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST17_-M2_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST04_M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST10_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST03-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST40_-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST05_M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST24_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST23_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST28_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST38_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST26_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST11_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST21_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST25_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST22_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST09-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST37_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST29_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST30_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST27_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST08-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST39_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST20_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST09_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST16_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST34-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST41_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST14_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST13_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST35-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST01-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST31_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST05-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST36_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST28_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST03_M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST21_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST26_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST38_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST04-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST23_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST24_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST17_TRACE_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST02_M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST12_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST15_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST40_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST10-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST09_-M2_Fav.xlsx
# ✅ Saved: logs/SM-S938N_All.xlsx

# %%
import os, _common, _map, _plot, _trend
df = _common.analyze_kpi(
    fname = os.path.join("logs",f"SM-S938N_All.xlsx"),
    date_list = [
        # "251016",
        # "251017",
        # "251020",
        # "251021",
        "251022", # pdcch dynamic 적용
        "251023",
        "251024",
        "251027",
    ],
)
df_all = df[df["route"]!="Fixed"].copy()

out_dir = os.path.join("results", "All")
os.makedirs(out_dir, exist_ok=True)

_map.map_pct(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
_map.map_db(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
_map.map_coverage(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
# _trend.kpi_each_test(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)

site_list = [
    'Huam415-1',
    'Huam345-5',
    'Namsan',
    'Fixed',
]
for site in site_list:
    df_site = df[df["route"]==site].copy()
    
    out_dir = os.path.join("results", site)
    os.makedirs(out_dir, exist_ok=True)
    
    _map.map_pct(df=df_site, out_dir=out_dir, grid_size=5, rb_min=48, sample_min=2)
    # _trend.kpi_each_test(df=df_site, out_dir=out_dir, grid_size=5, rb_min=48, sample_min=2)
    # _trend.rb_each_test(df=df_site, out_dir=out_dir, rb_min=0)
# Out:
# Reading logs/SM-S938N_All.xlsx
# ✅ Read Complete : 94800 lines
# ✅ Saved: results/All/map_25m_DL_Tput_ratio.html (rows=213)
# ✅ Saved: results/All/map_25m_RSRP_diff.html (rows=213)
# ✅ Saved: results/All/map_25m_RSRP_n28.html (rows=213)
# ✅ Saved: results/All/map_25m_DL_Tput_n28.html (rows=213)
# ✅ Saved: results/Huam415-1/map_5m_DL_Tput_ratio.html (rows=576)

# %%
# _plot.plot_kpi(df=df, grid_size=1, out_dir=out_dir, title=title)
# _plot.plot_tput_vs_sinr(df=df, grid_size=1, out_dir=out_dir, title=title)

# %%
import os, _common, _map, _plot, _trend

df = _common.analyze_kpi(
    fname = os.path.join("logs",f"SM-S938N_All.xlsx"),
    date_list = [
        # "251016",
        # "251017",
        # "251020",
        # "251021",
        "251022", # pdcch dynamic 적용
        "251023",
        "251024",
        "251027",
    ],
)
display(df)
# Out:
# Reading logs/SM-S938N_All.xlsx
# ✅ Read Complete : 94800 lines
#                      TIME    date      route              test_no        Lon  \
# 0     2025-10-22 14:51:48  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 1     2025-10-22 14:51:48  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 2     2025-10-22 14:51:49  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 3     2025-10-22 14:51:49  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 4     2025-10-22 14:51:50  251022  Huam415-1  251022_01_Huam415-1  126.98242
# ...                   ...     ...        ...                  ...        ...
# 64898 2025-10-27 17:36:25  251027  Huam345-5  251027_43_Huam345-5  126.98121
# 64899 2025-10-27 17:36:26  251027  Huam345-5  251027_43_Huam345-5  126.98120
# 64900 2025-10-27 17:36:26  251027  Huam345-5  251027_43_Huam345-5  126.98120
# 64901 2025-10-27 17:36:27  251027  Huam345-5  251027_43_Huam345-5  126.98120
# 64902 2025-10-27 17:36:27  251027  Huam345-5  251027_43_Huam345-5  126.98120
#
#             Lat    Distance Band    RSRP   RSRQ  ...  SINR_TRS    CQI   RI  \
# 0      37.54704  654.025416  n26  -59.96 -10.33  ...     33.63  14.00  2.0
# 1      37.54704  654.025416  n28  -63.39 -10.34  ...     40.34  13.33  2.0
# 2      37.54704  654.025416  n26  -63.92 -10.32  ...     33.53  14.00  2.0
# 3      37.54704  654.025416  n28  -65.35 -10.38  ...     40.46  13.25  2.0
# 4      37.54703  653.558332  n26  -64.63 -10.36  ...     33.54  14.00  2.0
# ...         ...         ...  ...     ...    ...  ...       ...    ...  ...
# 64898  37.55363  631.415974  n26  -92.07 -11.10  ...     26.79   7.00  2.0
# 64899  37.55363  632.211290  n28 -102.05 -12.95  ...     25.13  11.00  1.0
# 64900  37.55363  632.211290  n26  -91.30 -12.74  ...     24.90   8.00  2.0
# 64901  37.55363  632.211290  n28 -102.51 -13.15  ...     24.70  11.00  1.0
# 64902  37.55363  632.211290  n26  -92.27 -11.93  ...     22.08   8.33  1.0
#
#        DL_MCS  DL_BLER  UL_BLER  DL_RB  DL_Tput  DL_Tput_per_RB  \
# 0       19.19     8.78     0.00  49.84   79.905        1.603230
# 1       25.52     5.71     0.00  49.52  107.088        2.162520
# 2       21.69    10.72     0.00  49.78   91.579        1.839675
# 3       20.38     9.83     0.00  49.73   85.903        1.727388
# 4       22.83     6.26     3.12  49.41   95.911        1.941125
# ...       ...      ...      ...    ...      ...             ...
# 64898   13.70     8.18     3.08  49.87   55.003        1.102928
# 64899   15.13     6.69     3.08  49.75   35.549        0.714553
# 64900   13.34    11.00     0.00  49.78   53.611        1.076959
# 64901   20.79     9.04     3.03  49.73   42.725        0.859139
# 64902   14.28     6.50     0.00  49.56   36.704        0.740597
#
#        DL_Tput_full_RB
# 0            83.367978
# 1           112.451050
# 2            95.663078
# 3            89.824171
# 4           100.938514
# ...                ...
# 64898        57.352236
# 64899        37.156744
# 64900        56.001848
# 64901        44.675246
# 64902        38.511057
#
# [64903 rows x 22 columns]

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import os
import _common

def split_band_df(df_pair):
    common_cols = [c for c in df_pair.columns if not any(s in c for s in ["_n26", "_n28", "_diff"])]
    n26_cols = [c for c in df_pair.columns if c.endswith("_mean_n26")]
    n28_cols = [c for c in df_pair.columns if c.endswith("_mean_n28")]

    df_n26 = df_pair[common_cols + n26_cols].copy()
    df_n28 = df_pair[common_cols + n28_cols].copy()

    df_n26.columns = [c.replace("_mean_n26", "") for c in df_n26.columns]
    df_n28.columns = [c.replace("_mean_n28", "") for c in df_n28.columns]

    df_n26["Band"] = "n26"
    df_n28["Band"] = "n28"

    return df_n26, df_n28

def plot_rsrp_tput(df, out_dir, grid_size=25, rb_min=48, sample_min=10):
    df_pair = _common.grid_kpi(df, grid_size=grid_size, rb_min=rb_min, sample_min=sample_min)
    df_n26, df_n28 = split_band_df(df_pair)
    plot_df = pd.concat([df_n26, df_n28], ignore_index=True)

    # KPI 목록
    kpi_cols = [
        "RSRP", "RSRQ",
        "SINR", "SINR_TRS",
        "CQI", "RI", "DL_MCS",
        "DL_BLER", "UL_BLER",
        "DL_RB", "DL_Tput",
    ]

    # hover text 생성
    def make_hover_text(row):
        lines = [
            f"────────────────────────────",
            f"NR Band: {row['Band']}",
            f"Loc ID: {row['loc_id']}",
            f"UHD Max: {row['uhd_max']:.1f}",
            f"────────────────────────────",
            f"RSRP: {row['RSRP']:.1f}",
            f"DL Tput: {row['DL_Tput']:.1f}",
            f"────────────────────────────",
            f"RSRQ: {row['RSRQ']:.1f}",
            f"SINR: {row['SINR']:.1f}",
            f"SINR(TRS): {row['SINR_TRS']:.1f}",
            f"CQI: {row['CQI']:.1f}",
            f"RI: {row['RI']:.1f}",
            f"DL MCS: {row['DL_MCS']:.1f}",
            f"DL BLER: {row['DL_BLER']:.1f}",
            f"UL BLER: {row['UL_BLER']:.1f}",
        ]
        return "<br>".join(lines)

    plot_df["hover_text"] = plot_df.apply(make_hover_text, axis=1)

    color_map = {"n26": "blue", "n28": "red"}

    # Plotly scatter
    fig = px.scatter(
        plot_df,
        x="RSRP",
        y="DL_Tput",
        color="Band",
        color_discrete_map=color_map,
        custom_data=["loc_id", "Band"],  # ✅ loc_id & Band 전달
    )

    # hover 설정
    fig.update_traces(
        text=plot_df["hover_text"],
        hovertemplate=(
            "<b>NR Band:</b> %{customdata[1]}<br>"
            "<b>Loc ID:</b> %{customdata[0]}<br>"
            "────────────────────────────<br>"
            "%{text}<extra></extra>"
        ),
        hoverlabel=dict(
            bgcolor="white",
            bordercolor="gray",
            font=dict(size=11),
            align="left"
        ),
    )

    # x축 반전
    fig.update_xaxes(autorange="reversed")

    # 레이아웃
    fig.update_layout(
        title="DL_Tput over RSRP Scatter",
        xaxis_title="RSRP [dBm]",
        yaxis_title="DL Throughput [Mbps]",
        legend_title="NR Band",
        template="plotly_white",
    )

    # HTML 파일 저장
    os.makedirs(out_dir, exist_ok=True)
    out_path = os.path.join(out_dir, "scatter_tput_over_rsrp.html")
    map_url = "https://joostone-ahn.github.io/nr-field-analysis/results/All/map_25m_DL_Tput_n28.html"

    # 그래프 저장
    fig.write_html(out_path, include_plotlyjs="cdn")

    # 클릭 시 loc_id 연동 JS 추가
    js_script = f"""
    <script>
    window.addEventListener("DOMContentLoaded", function() {{
        const plotElement = document.querySelector('.plotly-graph-div');
        if (!plotElement) return;

        plotElement.on('plotly_click', function(e) {{
            if (e && e.points && e.points[0] && e.points[0].customdata) {{
                const loc_id = e.points[0].customdata[0];
                const url = '{map_url}?loc_id=' + loc_id;
                window.open(url, '_blank');
            }}
        }});
    }});
    </script>
    """

    # HTML에 JS 삽입
    with open(out_path, "a", encoding="utf-8") as f:
        f.write(js_script)

    print(f"✅ 산포도 저장 완료: {out_path}")
    return fig, plot_df


# ---------------------------
# 실행 예시
# ---------------------------
out_dir = os.path.join("results", "plot")
os.makedirs(out_dir, exist_ok=True)
fig, plot_df = plot_rsrp_tput(df, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
# Out:
# ✅ 산포도 저장 완료: results/plot/scatter_tput_over_rsrp.html

# %%
import numpy as np
import pandas as pd
import _common


def bin_kpi_each_band(df, band, grid_size, rb_min, sample_min, bin_size):

    # ---------------------------
    # Step 1. grid_kpi 실행
    # ---------------------------
    df_pair = _common.grid_kpi(df, grid_size=grid_size, rb_min=rb_min, sample_min=sample_min)

    # ---------------------------
    # Step 2. 밴드별 mean 컬럼 분리
    # ---------------------------
    common_cols = [c for c in df_pair.columns if not any(s in c for s in ["_n26", "_n28", "_diff"])]
    n26_cols = [c for c in df_pair.columns if c.endswith("_mean_n26")]
    n28_cols = [c for c in df_pair.columns if c.endswith("_mean_n28")]

    df_n26 = df_pair[common_cols + n26_cols].copy()
    df_n28 = df_pair[common_cols + n28_cols].copy()
    df_n26.columns = [c.replace("_mean_n26", "") for c in df_n26.columns]
    df_n28.columns = [c.replace("_mean_n28", "") for c in df_n28.columns]

    df_band = df_n26 if band == "n26" else df_n28

    # ---------------------------
    # Step 3. RSRP binning (범위 문자열로 표시)
    # ---------------------------
    rsrp_min = int(np.floor(df_band["RSRP"].min()))
    rsrp_max = int(np.ceil(df_band["RSRP"].max()))
    bins = np.arange(rsrp_min, rsrp_max + bin_size, bin_size)

    df_band["RSRP_bin"] = pd.cut(df_band["RSRP"], bins=bins, right=False)
    df_band["RSRP_bin"] = df_band["RSRP_bin"].apply(lambda x: f"[{int(x.left)}, {int(x.right)})")

    # ---------------------------
    # Step 4. KPI 컬럼 설정
    # ---------------------------
    kpi_cols=[
        "RSRP", "RSRQ", "SINR", "SINR_TRS",
        "CQI","RI","DL_MCS",
        "DL_Tput", "DL_RB",
        "DL_BLER", "UL_BLER",
    ]
    
    # ---------------------------
    # Step 5. bin별 KPI 평균 + loc_id/details 구조화
    # ---------------------------
    records = []
    grouped = df_band.groupby("RSRP_bin", observed=True)

    for bin_label, subdf in grouped:
        if subdf.empty:
            continue
        stats = {
            "RSRP_bin": bin_label,
            "count": len(subdf),
            "loc_ids": sorted(subdf["loc_id"].unique().tolist()),
            "details": subdf.apply(lambda r: r.to_dict(), axis=1).tolist()
        }
    
        kpi_means = {col: subdf[col].mean() for col in kpi_cols}
        stats.update(kpi_means)
        records.append(stats)

    df_binned = pd.DataFrame(records)
    df_binned["band"] = band

    return df_binned

# %%
df_n28 = bin_kpi_each_band(
    df,
    band="n28",
    grid_size=25,
    rb_min=48,
    sample_min=10,
    bin_size=1,
)

display(df_n28)
# Out:
#         RSRP_bin  count                                 loc_ids  \
# 0   [-119, -118)      1                                   [177]
# 1   [-118, -117)      4                    [185, 192, 193, 201]
# 2   [-117, -116)      4                    [188, 196, 199, 202]
# 3   [-116, -115)      2                              [189, 198]
# 4   [-115, -114)      3                         [184, 206, 207]
# 5   [-114, -113)      5               [176, 205, 210, 211, 212]
# 6   [-113, -112)      4                    [165, 203, 204, 213]
# 7   [-112, -111)      3                         [169, 170, 209]
# 8   [-111, -110)      5               [130, 136, 164, 200, 208]
# 9   [-110, -109)      6          [121, 139, 140, 144, 151, 174]
# 10  [-109, -108)      4                     [74, 129, 158, 175]
# 11  [-108, -107)      4                      [75, 79, 135, 157]
# 12  [-107, -106)      7      [86, 120, 150, 153, 181, 191, 197]
# 13  [-106, -105)      7        [78, 80, 87, 143, 168, 180, 183]
# 14  [-105, -104)      8  [34, 85, 112, 152, 156, 163, 190, 194]
# 15  [-104, -103)      8  [22, 29, 102, 113, 146, 179, 182, 195]
# 16  [-103, -102)      2                               [84, 186]
# 17  [-102, -101)      6            [33, 99, 145, 172, 173, 178]
# 18  [-101, -100)      9   [25, 26, 30, 35, 36, 38, 39, 98, 171]
# 19   [-100, -99)      7        [17, 31, 97, 100, 166, 167, 187]
# 20    [-99, -98)      4                    [101, 159, 160, 161]
# 21    [-97, -96)      2                              [131, 162]
# 22    [-96, -95)      7         [16, 21, 42, 96, 134, 149, 154]
# 23    [-95, -94)      4                         [9, 10, 14, 15]
# 24    [-94, -93)      4                     [20, 114, 122, 142]
# 25    [-93, -92)      6                  [1, 7, 8, 13, 95, 137]
# 26    [-92, -91)      6           [12, 103, 133, 138, 141, 155]
# 27    [-91, -90)      3                           [6, 123, 147]
# 28    [-90, -89)      1                                   [148]
# 29    [-89, -88)      5                   [41, 45, 46, 94, 105]
# 30    [-88, -87)      5                     [0, 2, 5, 104, 126]
# 31    [-87, -86)      5                 [43, 50, 124, 125, 127]
# 32    [-86, -85)      6               [4, 40, 44, 89, 111, 132]
# 33    [-85, -84)      2                                [32, 37]
# 34    [-84, -83)      2                                [27, 88]
# 35    [-83, -82)      2                                [49, 90]
# 36    [-82, -81)      2                               [82, 110]
# 37    [-80, -79)      3                            [28, 48, 81]
# 38    [-79, -78)      4                        [58, 73, 77, 83]
# 39    [-77, -76)      3                            [3, 47, 119]
# 40    [-76, -75)      2                                [23, 72]
# 41    [-75, -74)      3                           [24, 76, 109]
# 42    [-74, -73)      2                               [19, 118]
# 43    [-73, -72)      5                   [11, 18, 92, 93, 107]
# 44    [-72, -71)      3                           [51, 57, 108]
# 45    [-71, -70)      1                                    [62]
# 46    [-69, -68)      4                        [56, 61, 70, 71]
# 47    [-68, -67)      3                           [68, 91, 117]
# 48    [-67, -66)      5                    [52, 55, 59, 67, 69]
# 49    [-66, -65)      5                   [53, 54, 60, 63, 106]
# 50    [-65, -64)      1                                   [116]
# 51    [-64, -63)      2                                [64, 66]
# 52    [-63, -62)      1                                    [65]
# 53    [-54, -53)      1                                   [115]
# 54    [-53, -52)      1                                   [128]
#
#                                               details        RSRP       RSRQ  \
# 0   [{'loc_id': 177, 'lat_bin': 167221, 'lon_bin':... -118.199286 -15.633571
# 1   [{'loc_id': 185, 'lat_bin': 167223, 'lon_bin':... -117.452660 -15.218795
# 2   [{'loc_id': 188, 'lat_bin': 167224, 'lon_bin':... -116.476354 -14.529451
# 3   [{'loc_id': 189, 'lat_bin': 167224, 'lon_bin':... -115.594839 -14.234452
# 4   [{'loc_id': 184, 'lat_bin': 167223, 'lon_bin':... -114.165020 -14.595527
# 5   [{'loc_id': 176, 'lat_bin': 167221, 'lon_bin':... -113.590514 -15.063765
# 6   [{'loc_id': 165, 'lat_bin': 167219, 'lon_bin':... -112.598304 -14.718208
# 7   [{'loc_id': 169, 'lat_bin': 167220, 'lon_bin':... -111.362271 -14.291438
# 8   [{'loc_id': 130, 'lat_bin': 167213, 'lon_bin':... -110.585076 -14.778042
# 9   [{'loc_id': 121, 'lat_bin': 167212, 'lon_bin':... -109.415582 -15.081745
# 10  [{'loc_id': 74, 'lat_bin': 167206, 'lon_bin': ... -108.677600 -13.664494
# 11  [{'loc_id': 75, 'lat_bin': 167206, 'lon_bin': ... -107.352059 -12.664506
# 12  [{'loc_id': 86, 'lat_bin': 167208, 'lon_bin': ... -106.395826 -13.183833
# 13  [{'loc_id': 78, 'lat_bin': 167207, 'lon_bin': ... -105.601177 -12.421183
# 14  [{'loc_id': 34, 'lat_bin': 167184, 'lon_bin': ... -104.605017 -12.607320
# 15  [{'loc_id': 22, 'lat_bin': 167181, 'lon_bin': ... -103.521472 -12.555430
# 16  [{'loc_id': 84, 'lat_bin': 167208, 'lon_bin': ... -102.666632 -11.251076
# 17  [{'loc_id': 33, 'lat_bin': 167184, 'lon_bin': ... -101.626592 -11.663840
# 18  [{'loc_id': 25, 'lat_bin': 167182, 'lon_bin': ... -100.536080 -11.216570
# 19  [{'loc_id': 17, 'lat_bin': 167180, 'lon_bin': ...  -99.577610 -11.408969
# 20  [{'loc_id': 101, 'lat_bin': 167210, 'lon_bin':...  -98.454477 -12.692158
# 21  [{'loc_id': 131, 'lat_bin': 167213, 'lon_bin':...  -96.277152 -11.590394
# 22  [{'loc_id': 16, 'lat_bin': 167180, 'lon_bin': ...  -95.324568 -11.186499
# 23  [{'loc_id': 9, 'lat_bin': 167179, 'lon_bin': 4...  -94.479175 -11.223221
# 24  [{'loc_id': 20, 'lat_bin': 167181, 'lon_bin': ...  -93.449352 -10.930529
# 25  [{'loc_id': 1, 'lat_bin': 167178, 'lon_bin': 4...  -92.505841 -11.015081
# 26  [{'loc_id': 12, 'lat_bin': 167180, 'lon_bin': ...  -91.556904 -11.019540
# 27  [{'loc_id': 6, 'lat_bin': 167179, 'lon_bin': 4...  -90.613853 -10.953139
# 28  [{'loc_id': 148, 'lat_bin': 167216, 'lon_bin':...  -89.680812 -10.659615
# 29  [{'loc_id': 41, 'lat_bin': 167186, 'lon_bin': ...  -88.503921 -10.551666
# 30  [{'loc_id': 0, 'lat_bin': 167178, 'lon_bin': 4...  -87.377153 -10.666649
# 31  [{'loc_id': 43, 'lat_bin': 167187, 'lon_bin': ...  -86.504339 -10.499361
# 32  [{'loc_id': 4, 'lat_bin': 167179, 'lon_bin': 4...  -85.623480 -10.448208
# 33  [{'loc_id': 32, 'lat_bin': 167184, 'lon_bin': ...  -84.535930 -10.439929
# 34  [{'loc_id': 27, 'lat_bin': 167183, 'lon_bin': ...  -83.220433 -10.460052
# 35  [{'loc_id': 49, 'lat_bin': 167188, 'lon_bin': ...  -82.556448 -10.496496
# 36  [{'loc_id': 82, 'lat_bin': 167208, 'lon_bin': ...  -81.497777 -10.344716
# 37  [{'loc_id': 28, 'lat_bin': 167183, 'lon_bin': ...  -79.501911 -10.374494
# 38  [{'loc_id': 58, 'lat_bin': 167189, 'lon_bin': ...  -78.412508 -10.405156
# 39  [{'loc_id': 3, 'lat_bin': 167179, 'lon_bin': 4...  -76.354931 -10.366471
# 40  [{'loc_id': 23, 'lat_bin': 167182, 'lon_bin': ...  -75.258458 -10.348028
# 41  [{'loc_id': 24, 'lat_bin': 167182, 'lon_bin': ...  -74.464235 -10.343834
# 42  [{'loc_id': 19, 'lat_bin': 167181, 'lon_bin': ...  -73.260708 -10.337809
# 43  [{'loc_id': 11, 'lat_bin': 167180, 'lon_bin': ...  -72.422643 -10.340768
# 44  [{'loc_id': 51, 'lat_bin': 167189, 'lon_bin': ...  -71.439582 -10.356276
# 45  [{'loc_id': 62, 'lat_bin': 167199, 'lon_bin': ...  -70.316772 -10.377278
# 46  [{'loc_id': 56, 'lat_bin': 167189, 'lon_bin': ...  -68.783499 -10.345405
# 47  [{'loc_id': 68, 'lat_bin': 167203, 'lon_bin': ...  -67.231821 -10.332807
# 48  [{'loc_id': 52, 'lat_bin': 167189, 'lon_bin': ...  -66.646946 -10.341002
# 49  [{'loc_id': 53, 'lat_bin': 167189, 'lon_bin': ...  -65.420911 -10.344188
# 50  [{'loc_id': 116, 'lat_bin': 167211, 'lon_bin':...  -64.116615 -10.339231
# 51  [{'loc_id': 64, 'lat_bin': 167200, 'lon_bin': ...  -63.408981 -10.344958
# 52  [{'loc_id': 65, 'lat_bin': 167201, 'lon_bin': ...  -62.938861 -10.351944
# 53  [{'loc_id': 115, 'lat_bin': 167211, 'lon_bin':...  -53.197385 -10.328308
# 54  [{'loc_id': 128, 'lat_bin': 167212, 'lon_bin':...  -52.720385 -10.329615
#
#          SINR   SINR_TRS        CQI        RI     DL_MCS     DL_Tput  \
# 0   -4.042857   7.591429   3.362143  1.071429   2.470714    6.073000
# 1   -3.147224   6.913669   3.482654  1.065007   2.537717    6.089574
# 2   -1.720292   7.236463   3.642621  1.034375   2.496195    6.002977
# 3   -1.444396   8.267504   4.137931  1.007246   3.432834    7.804799
# 4   -1.797890  10.221075   5.368792  1.095220   4.291683    9.884495
# 5   -3.028201  11.283498   5.352692  1.142592   4.840205   11.492175
# 6   -2.253400  12.814019   6.045750  1.127346   6.217585   14.148006
# 7   -0.777719  11.471490   5.175535  1.000000   5.523531   11.948921
# 8   -1.358956  13.112536   6.270970  1.045308   5.829474   12.754234
# 9   -1.724993  14.365824   6.477778  1.057678   5.752081   12.703034
# 10   1.534972  15.290575   6.442120  1.080673   6.600909   14.381102
# 11   4.460072  15.786320   6.552852  1.064323   7.454395   16.036349
# 12   1.967107  18.540341   8.348602  1.092993   9.946778   21.016249
# 13   4.334810  17.587842   7.262969  1.128684   9.273949   19.980933
# 14   3.619707  20.402658   9.054321  1.159017  11.018685   24.360202
# 15   4.379066  20.913203   9.096671  1.174927  10.520436   24.472261
# 16   9.984514  23.147118   9.859514  1.204861  13.545278   31.010295
# 17   8.004223  24.413596   9.228975  1.317028  13.329982   32.575566
# 18   8.559065  22.949734   9.401731  1.168085  12.048650   27.477671
# 19   8.060404  24.184779   9.422737  1.266466  12.826591   30.722243
# 15  49.570540  9.059142   5.690333  n28
# 16  49.412951  9.361701   3.640243  n28
# 17  49.667254  9.120380   2.524442  n28
# 18  49.684779  9.100110   2.843174  n28
# 19  49.627143  9.093441   2.738985  n28
# 20  49.603317  9.222703   3.330006  n28
# 21  49.699394  9.686455   4.119424  n28
# 22  49.679597  9.241758   2.306661  n28
# 23  49.697062  9.194154   1.975931  n28
# 24  49.722680  9.439164   1.598949  n28
# 25  49.667161  9.249960   1.065308  n28
# 26  49.677010  9.420243   1.107367  n28
# 27  49.756794  8.942469   1.617370  n28
# 28  49.726795  9.286453   1.028632  n28
# 29  49.679048  9.325887   1.038752  n28
# 30  49.716801  9.357464   0.759240  n28
# 31  49.712415  9.352126   1.470273  n28
# 32  49.687837  9.338539   0.668101  n28
# 33  49.699949  9.351075   0.315928  n28
# 34  49.706092  9.688024   0.379054  n28
# 35  49.717447  9.541517   0.607986  n28
# 36  49.469118  8.712965   0.449578  n28
# 37  49.628868  9.196949   0.363574  n28
# 38  49.511619  8.648172   0.399931  n28
# 39  49.331753  8.252238   0.262612  n28
# 40  49.474365  7.748924   0.212743  n28
# 41  49.481798  7.906540   0.168981  n28
# 42  49.415102  6.998478   0.226100  n28
# 43  49.369465  6.169818   0.129658  n28
# 44  49.396485  7.850459   0.249998  n28
# 45  49.401203  7.816329   0.590633  n28
# 46  49.379893  8.408130   0.392637  n28
# 47  49.227074  6.569001   0.172478  n28
# 48  49.325462  8.106180   0.225724  n28
# 49  49.275367  7.364824   0.408501  n28
# 50  49.124615  7.528462   0.214615  n28
# 51  49.356470  7.234376   0.478251  n28
# 52  49.405778  6.022194   0.644333  n28
# 53  49.402769  3.520615   0.048462  n28
# 54  49.446538  3.096923   0.058462  n28

# %%
for i, row in df_n28.iterrows():
    print(f"{row['RSRP_bin']}: {row['count']} samples")
    print(pd.DataFrame(row["details"]))
    print()
    print()
# Out:
# [-119, -118): 1 samples
#    loc_id  lat_bin  lon_bin  \
# 0     177   167221   446969
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     11.0    -53.8
#
#    uhd_max  uhd_min        RSRP       RSRQ      SINR  SINR_TRS       CQI  \
# 0   -51.42    -55.8 -118.199286 -15.633571 -4.042857  7.591429  3.362143
#
#          RI    DL_MCS   DL_BLER    UL_BLER      DL_RB  DL_Tput      RSRP_bin
# 0  1.071429  2.470714  8.596429  51.073571  49.376429    6.073  [-119, -118)
#
#
# [-118, -117): 4 samples
#    loc_id  lat_bin  lon_bin  \
# 0     185   167223   446971
# 1     192   167225   446972
# 2     193   167225   446973
# 3     201   167228   446968
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     26.0   -50.52
# 1  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     31.0   -36.84
# 2  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...      1.0   -38.79
# 3  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     32.0   -38.95
#
#    uhd_max  uhd_min        RSRP       RSRQ      SINR  SINR_TRS       CQI  \
# 0   -47.96   -52.78 -117.627500 -14.630000 -1.057917  7.133333  3.791667
# 1   -33.10   -41.61 -117.364231 -14.732692 -1.548846  8.043846  3.817308
# 2   -38.79   -38.79 -117.577619 -16.175714 -6.227619  5.665238  3.198095
# 3   -32.84   -44.35 -117.241290 -15.336774 -3.754516  6.812258  3.123548
#
#          RI    DL_MCS    DL_BLER    UL_BLER      DL_RB   DL_Tput      RSRP_bin
# 0  1.041667  2.758333   7.931250  60.423750  49.073750  6.287583  [-118, -117)
# 1  1.153846  3.038846   9.408462  24.431154  49.403077  7.492038  [-118, -117)
# 2  1.000000  2.341429   8.629524  30.885238  49.096190  5.483095  [-118, -117)
# 3  1.064516  2.012258  10.197742  33.940323  49.060645  5.095581  [-118, -117)
#
#
# [-117, -116): 4 samples
#    loc_id  lat_bin  lon_bin  \
# 
L_MCS   DL_BLER    UL_BLER      DL_RB    DL_Tput      RSRP_bin
# 0  1.107595  7.728861  9.257722   5.900759  49.729114  16.609861  [-108, -107)
# 1  1.076355  7.731478  9.150936   8.012340  49.645000  16.622995  [-108, -107)
# 2  1.017341  6.701561  9.031850  14.029884  49.752832  14.390116  [-108, -107)
# 3  1.056000  7.655680  9.169840  11.536320  49.749840  16.522424  [-108, -107)
#
#
# [-107, -106): 7 samples
#    loc_id  lat_bin  lon_bin  \
# 0      86   167208   447007
# 1     120   167212   446967
# 2     150   167217   446964
# 3     153   167217   446967
# 4     181   167222   446963
# 5     191   167225   446959
# 6     197   167227   446958
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      2.0   -28.79
# 1  [251022_27_Huam345-5, 251022_28_Huam345-5, 251...      4.0   -49.43
# 2  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     14.0   -44.93
# 3  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     29.0   -46.07
# 4  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     20.0   -40.20
# 5  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     10.0   -32.40
# 6  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     23.0   -32.84
#
#    uhd_max  uhd_min        RSRP       RSRQ      SINR   SINR_TRS       CQI  \
# 0   -27.39   -30.19 -106.066910 -10.969648  9.853844  18.409397  7.479196
# 1   -48.38   -52.00 -106.188182 -13.149091  2.058182  20.362727  8.651818
# 2   -40.09   -47.69 -106.266972 -13.846881 -0.160367  16.383578  6.502844
# 3   -43.06   -49.14 -106.356333 -14.776556 -1.442667  19.504000  8.308444
# 4   -38.05   -43.85 -106.552128 -13.825319 -0.286596  19.393404  9.347447
# 5   -29.86   -35.83 -106.777551 -12.412041  3.258163  19.393878  9.848571
# 6   -28.69   -36.26 -106.562703 -13.307297  0.489189  16.335405  8.301892
#
#          RI     DL_MCS   DL_BLER    UL_BLER      DL_RB    DL_Tput  \
# 0  1.077889  10.643744  9.084497   6.165528  49.614397  22.357658
# 1  1.090909  10.240000  8.548182   5.741818  49.702727  20.991091
# 2  1.211009   7.345138  9.516330  10.254954  49.632661  16.723963
# 3  1.122222   9.098111  9.118667   5.977333  49.637222  20.337656
# 4  1.000000  10.323191  8.846809   5.251489  49.504894  20.917255
# 5  1.040816  12.775102  8.787347   3.500612  49.280816  26.326041
# 6  1.108108   9.202162  8.997568   5.401892  49.386757  19.460081
#
#        RSRP_bin
# 0  [-107, -106)
# 1  [-107, -106)
# 2  [-107, -106)
# 3  [-107, -106)
# 4  [-107, -106)
# 5  [-107, -106)
# 6  [-107, -106)
#
#
# [-106, -105): 7 samples
#    loc_id  lat_bin  lon_bin  \
# 0      78   167207   447007
# 1      80   167207   447009
# 2      87   167208   447008
# 3     143   167216   446964
# 4     168   167220   446965
# 5     180   167222   446962
# 6     183   167223   446962
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      NaN      NaN
# 1  [251023_04_Namsan, 251023_13_Namsan, 251023_15...      NaN      NaN
# 2  [251023_04_Namsan, 251023_05_Namsan, 251023_06...      1.0   -21.65
# 3  [251022_28_Huam345-5, 251022_29_Huam345-5, 251...      1.0   -45.15
# 4  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     25.0   -43.21
# 5  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     21.0   -40.17
# 6  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...      6.0   -40.87
#
#    uhd_max  uhd_min        RSRP       RSRQ      SINR   SINR_TRS       CQI  \
# 0      NaN      NaN -105.791471 -11.025478  9.181691  16.520037  5.989522
# 1      NaN      NaN -105.952727 -10.944091  9.955455  13.641364  5.591364
# 2   -21.65   -21.65 -105.787955 -11.273864  8.445682  15.417273  6.712273
# 3   -45.15   -45.15 -105.438161 -14.845977 -2.260920  14.334483  5.297816
# 4   -34.91   -48.48 -105.440426 -13.493085  0.102021  20.565000  7.802021
# 5   -35.54   -43.92 -105.565000 -12.704286  2.345238  20.805238  9.889286
# 6   -39.51   -42.83 -105.232500 -12.661500  2.574500  21.831500  9.558500
#
#          RI     DL_MCS    DL_BLER    UL_BLER      DL_RB    DL_Tput  \
# 0  1.062500   8.492978   9.126066   5.600257  49.669007  17.942007
# 1  1.181818   7.113182   9.000455   7.822273  49.695000  16.700182
# 2  1.068182   9.042727   9.122500   5.848182  49.705227  18.961636
# 3  1.471264   5.084943  11.031149  11.422184  49.709195  12.831356
# 4  1.117021  10.718191   9.280532   6.383617  49.703085  23.303298
# 5  1.000000  11.932619   9.709286   5.087143  49.552619  24.394952
# 6  1.000000  12.533000   8.994500   4.427000  49.699500  25.733100
#
#        RSRP_bin
# 0  [-106, -105)
# 1  [-106, -105)
# 2  [-106, -105)
# 3  [-106, -105)
# 4  [-106, -105)
# 5  [-106, -105)
# 6  [-106, -105)
#
#
# [-105, -104): 8 samples
#    loc_id  lat_bin  lon_bin  \
# 0      34   167184   446983
# 1      85   167208   447006
# 2     112   167211   446968
# 3     152   167217   446966
# 4     156   167218   446964
# 5     163   167219   446965
# 6     190   167225   446958
# 7     194   167226   446957
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_30_Huam415-1, 251022_31_Huam415-1, 251...      9.0   -47.16
# 1  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      1.0   -33.69
# 2  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     12.0   -46.45
# 3  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...      4.0   -43.72
# 4  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     14.0   -45.23
# 5  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     27.0   -43.67
# 6  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     25.0   -33.79
# 7  [251022_17_Huam345-5, 251022_38_Huam345-5, 251...      8.0   -33.82
#
#    uhd_max  uhd_min        RSRP       RSRQ       SINR   SINR_TRS       CQI  \
# 0   -45.05   -50.92 -104.971887 -10.989245   7.980755  19.939623  9.649245
# 1   -33.69   -33.69 -104.840247 -10.749776  12.314574  20.388363  8.077556
# 2   -42.04   -51.41 -104.154884 -13.064070   2.485698  21.453372  9.445465
# 3   -39.68   -47.16 -104.178000 -14.354000  -0.442444  23.999778  8.744444
# 4   -40.38   -50.12 -104.604211 -12.486316   3.190877  20.283333  9.644561
# 5   -39.08   -49.34 -104.286389 -13.423056  -0.022222  20.834167  9.015972
# 6   -30.26   -37.24 -104.856829 -12.889024   1.764268  19.458780  9.299634
# 7   -30.06   -36.35 -104.947692 -12.903077   1.686154  16.863846  8.557692
#
#          RI     DL_MCS   DL_BLER    UL_BLER      DL_RB    DL_Tput  \
# 0  1.150943  12.010755  9.037736   4.393396  49.786415  25.712755
# 1  1.121076  11.805762  9.148498   6.158969  49.598363  25.746011
# 2  1.081395  10.239535  9.143953   9.868488  49.590116  22.056058
# 3  1.200000  11.662889  9.414889   4.229111  49.670222  27.286489
# 4  1.052632  12.248070  9.144386   4.966667  49.615614  25.288860
# 5  1.138889  10.279861  9.165139  10.301944  49.559444  23.262514
# 6  1.219512  11.124146  9.119146   4.763293  49.420244  25.130854
# 7  1.307692   8.778462  8.773077   2.633077  49.252308  20.398077
#
#        RSRP_bin
# 0  [-105, -104)
# 1  [-105, -104)
# 2  [-105, -104)
# 3  [-105, -104)
# 4  [-105, -104)
# 5  [-105, -104)
# 6  [-105, -104)
# 7  [-105, -104)
#
#
# [-104, -103): 8 samples
#    loc_id  lat_bin  lon_bin  \
# 0      22   167181   446986
# 1      29   167183   446982
# 2     102   167210   446971
# 3     113   167211   446969
# 4     146   167216   446967
# 5     179   167221   446974
# 6     182   167223   446961
# 7     195   167226   446958
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     34.0   -38.75
# 1  [251022_30_Huam415-1, 251022_31_Huam415-1, 251...      7.0   -41.56
# 2  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     21.0   -35.06
# 3  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...      7.0   -44.58
# 4  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...      6.0   -44.07
# 5  [251022_20_Huam345-5, 251022_21_Huam345-5, 251...     15.0   -35.97
# 6  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     26.0   -36.66
# 7  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     20.0   -33.93
#
#    uhd_max  uhd_min        RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -34.24   -45.74 -103.002926 -12.807814   3.877621  16.293087   6.823248
# 1   -33.92   -48.47 -103.645660 -10.836792  10.334906  24.761509  10.519245
# 2   -30.89   -43.44 -103.225313 -12.470232   5.877843  18.666300   8.667933
# 3   -41.58   -49.35 -103.544634 -12.605707   3.590927  22.408293  10.014244
# 4   -42.69   -45.54 -103.991607 -15.405536  -2.190179  22.644286   9.730714
# 5   -30.30   -43.12 -103.948489 -11.447289   6.789244  21.464311   7.239556
# 6   -33.31   -40.44 -103.641176 -12.237647   4.106863  19.526471   9.815098
# 7   -29.29   -38.91 -103.171970 -12.632424   2.645303  21.541364   9.963333
#
#          RI     DL_MCS   DL_BLER    UL_BLER      DL_RB    DL_Tput  \
# 0  1.070740   7.057460  9.157299   3.883923  49.702669  15.594984
# 1  1.226415  13.836226  9.138868   3.072264  49.723019  33.312774
# 2  1.138105   8.793478  9.076058  16.469546  49.674627  19.902369
# 3  1.126829  10.002683  9.140537   5.523463  49.479268  22.188766
# 4  1.089286  11.519821  8.783393   3.198393  49.480893  24.046875
# 5  1.231111  10.395600  9.086667   4.105956  49.780311  23.983342
# 6  1.274510   9.392157  8.934706   5.594118  49.313529  27.188647
# 7  1.242424  13.166061  9.155606   3.675000  49.410000  29.560333
#
#        RSRP_bin
# 0  [-104, -103)
# 1  [-104, -103)
# 2  [-104, -103)
# 3  [-104, -103)
# 4  [-104, -103)
# 5  [-104, -103)
# 6  [-104, -103)
# 7  [-104, -103)
#
#
# [-103, -102): 2 samples
#    loc_id  lat_bin  lon_bin  \
# 0      84   167208   447005
# 1     186   167224   446959
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251023_12_Namsan, 251023_14_Namsan, 251023_15...      1.0   -36.05
# 1  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     15.0   -33.31
#
#    uhd_max  uhd_min        RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -36.05   -36.05 -102.629375 -10.571875  15.068750  23.160625   9.041250
# 1   -29.05   -37.11 -102.703889 -11.930278   4.900278  23.133611  10.677778
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput      RSRP_bin
# 0  1.187500  13.797500  8.778125  3.319375  49.543125  31.918312  [-103, -102)
# 1  1.222222  13.293056  9.945278  3.961111  49.282778  30.102278  [-103, -102)
#
#
# [-102, -101): 6 samples
#    loc_id  lat_bin  lon_bin  \
# 0      33   167184   446982
# 1      99   167209   447006
# 2     145   167216   446966
# 3     172   167220   446973
# 4     173   167220   446974
# 5     178   167221   446973
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_30_Huam415-1, 251022_31_Huam415-1, 251...      2.0   -45.68
# 1  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      NaN      NaN
# 2  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     28.0   -44.55
# 3  [251022_21_Huam345-5, 251022_22_Huam345-5, 251...      3.0   -35.03
# 4  [251022_20_Huam345-5, 251022_21_Huam345-5, 251...     42.0   -37.70
# 5  [251022_21_Huam345-5, 251022_22_Huam345-5, 251...     39.0   -35.05
#
#    uhd_max  uhd_min        RSRP       RSRQ       SINR   SINR_TRS       CQI  \
# 0   -44.83   -46.53 -101.803038 -10.824684   9.723418  25.918734  9.324937
# 1      NaN      NaN -101.837885 -10.547885  14.329038  22.675385  8.504615
# 2   -40.78   -49.40 -101.450000 -15.307931  -2.321954  25.249425  9.815402
# 3   -34.83   -35.42 -101.640286 -11.020857   9.045429  24.029143  9.876000
# 4   -29.99   -42.89 -101.782103 -11.227179   8.113128  23.982359  8.617897
# 5   -31.57   -40.19 -101.246240 -11.054504   9.136281  24.626529  9.235000
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput      RSRP_bin
# 0  1.645570  12.243291  9.100759  2.589114  49.731772  36.987785  [-102, -101)
# 1  1.269231  12.258654  9.101731  3.958269  49.465000  28.215269  [-102, -101)
# 2  1.333333  12.181609  9.298736  2.953563  49.488391  30.265931  [-102, -101)
# 3  1.085714  15.578571  9.041429  1.005714  49.767714  33.884886  [-102, -101)
# 4  1.266667  13.297436  9.104256  2.329744  49.804615  31.462313  [-102, -101)
# 5  1.301653  14.420331  9.075372  2.310248  49.746033  34.637211  [-102, -101)
#
#
# [-101, -100): 9 samples
#    loc_id  lat_bin  lon_bin  \
# 0      25   167182   446982
# 1      26   167182   446986
# 2      30   167183   446985
# 3      35   167184   446984
# 4      36   167184   446985
# 5      38   167185   446983
# 6      39   167185   446984
# 7      98   167209   447005
# 8     171   167220   446972
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_30_Huam415-1, 251022_31_Huam415-1, 251...      8.0   -46.06
# 1  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     28.0   -39.56
# 2  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     15.0   -42.73
# 3  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     23.0   -48.64
# 4  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     21.0   -47.90
# 5  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     16.0   -48.50
# 6  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     22.0   -48.69
# 7  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      7.0   -34.02
# 8  [251022_21_Huam345-5, 251022_22_Huam345-5, 251...     33.0   -33.73
#
#    uhd_max  uhd_min        RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -42.33   -50.61 -100.757468 -11.723671   6.568354  27.190380  10.486329
# 1   -32.61   -44.42 -100.191801 -11.859668   4.838947  20.938643   8.906537
# 2   -38.38   -46.66 -100.772360 -11.282809   7.834607  20.012584   8.862360
# 3   -43.16   -52.75 -100.564237 -11.053305   8.253898  20.794322   9.908898
# 4   -36.54   -53.81 -100.704099 -11.129876   8.347267  22.777826   9.250807
# 5   -39.65   -52.12 -100.923971 -11.098015   8.700294  22.945147   9.963897
# 6   -42.16   -51.69 -100.584054 -11.346306   7.921351  22.651892   8.716441
# 7   -26.19   -42.33 -100.103708 -10.545479  14.709583  24.029771   9.189479
# 8   -31.02   -36.89 -100.223018 -10.910000   9.857278  25.207041   9.330828
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput      RSRP_bin
# 0  1.531646  14.809367  9.071899  2.080253  49.638861  42.372772  [-101, -100)
# 1  1.083102  10.306565  9.205346  2.460693  49.608947  21.868471  [-101, -100)
# 2  1.011236  10.067416  9.158876  2.775618  49.741910  20.303348  [-101, -100)
# 3  1.080508  11.549958  9.109831  3.186229  49.668305  24.319746  [-101, -100)
# 4  1.037267  11.148012  9.102422  3.550621  49.756708  22.938075  [-101, -100)
# 5  1.051471  11.446029  9.040809  3.081250  49.697279  23.802338  [-101, -100)
# 6  1.180180  10.451937  9.020360  3.472658  49.754279  24.152559  [-101, -100)
# 7  1.312500  13.606021  9.096125  3.122958  49.517729  32.583242  [-101, -100)
# 8  1.224852  15.052544  9.095325  1.858284  49.778994  34.958485  [-101, -100)
#
#
# [-100, -99): 7 samples
#    loc_id  lat_bin  lon_bin  \
# 0      17   167180   446986
# 1      31   167183   446986
# 2      97   167209   447004
# 3     100   167210   446969
# 4     166   167219   446973
# 5     167   167219   446974
# 6     187   167224   446960
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...      5.0   -41.51
# 1  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     28.0   -41.48
# 2  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      6.0   -28.33
# 3  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     17.0   -38.05
# 4  [251022_20_Huam345-5, 251022_21_Huam345-5, 251...     40.0   -37.74
# 5  [251022_20_Huam345-5, 251022_21_Huam345-5, 251...      3.0   -36.04
# 6  [251022_16_Huam345-5, 251022_17_Huam345-5, 251...     27.0   -34.25
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -40.01   -44.70 -99.093538 -12.023077   5.502000  20.127692   7.696000
# 1   -28.71   -50.37 -99.270744 -11.247107   7.710413  23.065496   9.088347
# 2   -20.52   -33.89 -99.863921 -10.600675  13.629362  23.861482   9.280694
# 3   -32.48   -41.80 -99.708894 -12.295714   4.133687  23.765438  10.498018
# 4   -31.04   -43.67 -99.426368 -11.028504   9.945855  26.386496   9.750214
# 5   -33.93   -38.18 -99.912766 -10.901596   9.620213  26.169255   9.582553
# 6   -31.77   -36.16 -99.767037 -11.766111   5.881296  25.917593  10.063333
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput     RSRP_bin
# 0  1.153846   9.218462  9.196154  3.436154  49.761538  20.527308  [-100, -99)
# 1  1.103306  10.959793  9.121405  2.521322  49.645702  23.184975  [-100, -99)
# 2  1.281426  13.874146  9.119644  2.558518  49.610432  33.115463  [-100, -99)
# 3  1.152074  11.978618  9.182673  3.682028  49.391014  26.447037  [-100, -99)
# 4  1.329060  14.669444  9.054915  2.002863  49.718590  37.320406  [-100, -99)
# 5  1.308511  15.752340  9.156702  1.645532  49.799574  37.477862  [-100, -99)
# 6  1.537037  13.333333  8.822593  3.326481  49.463148  36.982648  [-100, -99)
#
#
# [-99, -98): 4 samples
#    loc_id  lat_bin  lon_bin  \
# 0     101   167210   446970
# 1     159   167218   446973
# 2     160   167218   446974
# 3     161   167218   446975
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     17.0   -35.49
# 1  [251022_24_Huam345-5, 251023_01_Huam345-5, 251...      1.0   -36.66
# 2  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      9.0   -38.00
# 3  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      9.0   -33.56
#
#    uhd_max  uhd_min       RSRP       RSRQ      SINR   SINR_TRS        CQI  \
# 0   -31.83   -40.68 -98.669125 -12.180750  4.911750  25.533031  11.201063
# 1   -36.66   -36.66 -98.874302 -12.801279  2.079884  26.592442   9.781047
# 2   -35.11   -41.25 -98.230847 -12.678508  1.828068  27.431424  10.415627
# 3   -30.84   -37.97 -98.043633 -13.108094  0.820971  26.991583  10.603669
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  1.196875  13.164562  9.130625  3.326938  49.452375  29.521794  [-99, -98)
# 1  1.546512  13.745698  9.210349  4.229535  49.738605  40.761047  [-99, -98)
# 2  1.505085  14.735390  9.346780  3.138983  49.624339  41.197566  [-99, -98)
# 3  1.420863  15.543561  9.203058  2.624568  49.597950  41.551335  [-99, -98)
#
#
# [-97, -96): 2 samples
#    loc_id  lat_bin  lon_bin  \
# 0     131   167213   446969
# 1     162   167218   446976
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      6.0   -41.43
# 1  [251022_20_Huam345-5, 251027_33_Huam345-5, 251...      2.0   -31.74
#
#    uhd_max  uhd_min       RSRP       RSRQ      SINR   SINR_TRS        CQI  \
# 0   -36.92   -44.08 -96.123636 -11.345455  7.445455  29.120909   9.439091
# 1   -29.58   -33.91 -96.430667 -11.835333  5.432000  28.568000  11.188667
#
#     RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  2.0  12.061818  9.530909  6.728182  49.765455  46.727818  [-97, -96)
# 1  1.6  16.408667  9.842000  1.510667  49.633333  49.021067  [-97, -96)
#
#
# [-96, -95): 7 samples
#    loc_id  lat_bin  lon_bin  \
# 0      16   167180   446985
# 1      21   167181   446981
# 2      42   167186   446983
# 3      96   167209   447003
# 4     134   167213   446978
# 5     149   167216   446978
# 6     154   167217   446976
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     26.0   -39.29
# 1  [251022_30_Huam415-1, 251022_31_Huam415-1, 251...      9.0   -43.15
# 2  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     31.0   -47.61
# 3  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      6.0   -25.97
# 4                              [251027_33_Huam345-5]      NaN      NaN
# 5  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      5.0   -36.31
# 6  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      7.0   -32.32
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -34.67   -45.98 -95.325585 -11.346702   6.637713  25.826330   9.994787
# 1   -34.80   -46.39 -95.290233 -11.903721   5.447674  31.289535  10.085116
# 2   -39.15   -54.22 -95.630033 -10.748371  12.762997  28.786254  11.707915
# 3   -19.74   -31.70 -95.873993 -10.470765  17.251065  26.232879  10.251830
# 4      NaN      NaN -95.028571 -11.185000   7.602857  29.068571  11.232857
# 5   -30.82   -39.65 -95.096541 -10.853083   9.967218  30.202256  10.300977
# 6   -29.71   -36.33 -95.027020 -11.797848   5.579305  30.418907  10.302483
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  1.319149  12.683191  9.223085  2.479521  49.654415  30.793213  [-96, -95)
# 1  1.953488  13.597907  9.290465  1.622326  49.686977  51.257977  [-96, -95)
# 2  1.234528  14.697199  9.206287  2.758111  49.699544  36.241261  [-96, -95)
# 3  1.307820  16.180732  9.123927  1.444010  49.641198  39.594161  [-96, -95)
# 4  1.500000  15.030714  9.293571  4.857857  49.640714  42.975071  [-96, -95)
# 5  1.766917  15.165714  9.226692  1.486391  49.733008  51.080098  [-96, -95)
# 6  1.811258  14.898576  9.328278  1.498411  49.701325  52.742570  [-96, -95)
#
#
# [-95, -94): 4 samples
#    loc_id  lat_bin  lon_bin  \
# 0       9   167179   446983
# 1      10   167179   446984
# 2      14   167180   446983
# 3      15   167180   446984
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     21.0   -42.58
# 1  [251024_11_Huam415-1, 251024_13_Huam415-1, 251...      5.0   -42.99
# 2  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...      5.0   -48.22
# 3  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     34.0   -38.61
#
#    uhd_max  uhd_min       RSRP       RSRQ      SINR   SINR_TRS        CQI  \
# 0   -36.59   -49.95 -94.598353 -11.172588  8.641059  28.616235   9.654824
# 1   -34.11   -65.16 -94.889231 -11.534615  5.993846  24.089231  10.217692
# 2   -31.39   -65.04 -94.186452 -10.993871  9.440323  29.126774   9.851935
# 3   -29.06   -67.03 -94.242667 -11.191810  7.884190  26.594095   9.852952
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  1.635294  11.988353  9.317765  1.520235  49.724118  35.470953  [-95, -94)
# 1  1.153846  12.973846  9.202308  2.551538  49.656923  28.643385  [-95, -94)
# 2  1.612903  12.153226  9.192258  1.472903  49.718065  35.675419  [-95, -94)
# 3  1.200000  12.319810  9.064286  2.359048  49.689143  28.938219  [-95, -94)
#
#
# [-94, -93): 4 samples
#    loc_id  lat_bin  lon_bin  \
# 0      20   167181   446980
# 1     114   167211   446971
# 2     122   167212   446971
# 3     142   167215   446978
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_30_Huam415-1, 251022_31_Huam415-1, 251...      NaN      NaN
# 1                                  [251024_27_Fixed]      NaN      NaN
# 2  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      7.0   -36.24
# 3  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      7.0   -36.81
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0      NaN      NaN -93.071304 -11.181739   8.138261  31.083478  10.847826
# 1      NaN      NaN -93.349545 -10.810825   8.222828  32.326768  10.273468
# 2   -31.37   -39.01 -93.742308 -10.944615   9.710769  30.978462  10.608462
# 3   -30.49   -40.34 -93.634250 -10.784937  11.415313  31.579125  10.317125
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  2.000000  14.439565  9.360435  1.468696  49.681304  58.124130  [-94, -93)
# 1  1.978114  15.524057  9.516431  0.945320  49.678266  61.856338  [-94, -93)
# 2  2.000000  13.492308  9.411538  2.856154  49.778462  53.940538  [-94, -93)
# 3  1.912500  15.521187  9.468250  1.125625  49.752688  58.411600  [-94, -93)
#
#
# [-93, -92): 6 samples
#    loc_id  lat_bin  lon_bin  \
# 0       1   167178   446977
# 1       7   167179   446981
# 2       8   167179   446982
# 3      13   167180   446980
# 4      95   167209   447002
# 5     137   167214   446977
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     33.0   -43.89
# 1  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     30.0   -44.90
# 2  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     36.0   -45.25
# 3  [251022_04_Huam415-1, 251022_07_Huam415-1, 251...      9.0   -41.84
# 4  [251023_01_Namsan, 251023_02_Namsan, 251023_03...      6.0   -26.93
# 5  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...     10.0   -33.03
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -37.76   -47.53 -92.381937 -10.742027  12.386802  32.425315  12.015901
# 1   -38.19   -51.33 -92.496772 -11.361582   7.053797  29.628481  10.465380
# 2   -39.04   -52.33 -92.308897 -11.200483   8.866000  30.518483  10.564621
# 3   -36.81   -48.73 -92.858571 -11.501270   6.770317  31.284603  10.433968
# 4   -23.25   -34.65 -92.676503 -10.431608  19.682587  27.911072  10.733590
# 5   -28.58   -41.16 -92.312364 -10.853515  11.223121  31.984485  10.844758
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  1.567568  16.245180  9.134414  0.714595  49.702658  47.868703  [-93, -92)
# 1  1.500000  12.957025  9.188734  0.935823  49.687848  35.142051  [-93, -92)
# 2  1.758621  12.010552  9.365931  1.370000  49.668414  40.047421  [-93, -92)
# 3  1.904762  13.325397  9.327619  0.969206  49.675079  50.555730  [-93, -92)
# 4  1.575758  16.456270  9.179394  1.435105  49.587179  49.345149  [-93, -92)
# 5  1.839394  16.473394  9.303667  0.967121  49.681788  59.923176  [-93, -92)
#
#
# [-92, -91): 6 samples
#    loc_id  lat_bin  lon_bin  \
# 0      12   167180   446979
# 1     103   167210   446972
# 2     133   167213   446977
# 3     138   167214   446978
# 4     141   167215   446977
# 5     155   167217   446977
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_04_Huam415-1, 251022_08_Huam415-1, 251...      1.0   -42.68
# 1  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     19.0   -32.63
# 2  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      9.0   -33.45
# 3  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...      NaN      NaN
# 4  [251022_24_Huam345-5, 251023_01_Huam345-5, 251...      1.0   -35.17
# 5  [251022_20_Huam345-5, 251022_24_Huam345-5, 251...
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  2.000000  22.799167  8.996845  0.369405  49.364762   95.242399  [-72, -71)
# 1  1.959854  21.075766  9.067920  0.289854  49.530000   86.062923  [-72, -71)
# 2  2.000000  25.391959  5.486612  0.090735  49.294694  106.440853  [-72, -71)
#
#
# [-71, -70): 1 samples
#    loc_id  lat_bin  lon_bin  \
# 0      62   167199   446976
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251024_01_Huam345-5, 251024_02_Huam345-5, 251...     10.0   -34.11
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -25.79    -45.8 -70.316772 -10.377278  24.105443  34.825063  14.109304
#
#     RI     DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  2.0  24.859494  7.816329  0.590633  49.401203  104.747747  [-71, -70)
#
#
# [-69, -68): 4 samples
#    loc_id  lat_bin  lon_bin  \
# 0      56   167189   446979
# 1      61   167190   446979
# 2      70   167204   446975
# 3      71   167205   446974
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     33.0   -35.76
# 1  [251022_01_Huam415-1, 251022_03_Huam415-1, 251...      3.0   -34.88
# 2  [251022_27_Huam345-5, 251022_28_Huam345-5, 251...      3.0   -40.35
# 3  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     21.0   -45.63
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -29.67   -42.93 -68.691266 -10.354253  28.743474  39.613409  13.655584
# 1   -32.99   -38.19 -68.571964 -10.350000  30.137857  39.489286  13.452500
# 2   -40.20   -40.59 -68.894318 -10.338182  33.788182  34.156364  14.776591
# 3   -41.59   -49.15 -68.976449 -10.339184  33.897796  34.051143  14.127714
#
#          RI     DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  2.000000  23.090584  8.889708  0.604740  49.336234   96.679601  [-69, -68)
# 1  2.000000  21.461607  8.884643  0.805357  49.574643   89.763482  [-69, -68)
# 2  2.000000  25.247500  7.850455  0.000000  49.238409  106.050886  [-69, -68)
# 3  1.991837  24.033510  8.007714  0.160449  49.370286  100.410902  [-69, -68)
#
#
# [-68, -67): 3 samples
#    loc_id  lat_bin  lon_bin  \
# 0      68   167203   446975
# 1      91   167209   446996
# 2     117   167211   446998
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     15.0   -38.09
# 1  [251023_03_Namsan, 251023_06_Namsan, 251023_08...      NaN      NaN
# 2  [251023_02_Namsan, 251023_03_Namsan, 251023_06...      NaN      NaN
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -28.99   -45.27 -67.028146 -10.344488  33.181512  34.092390  14.625268
# 1      NaN      NaN -67.286327 -10.332041  32.115918  30.582857  14.678367
# 2      NaN      NaN -67.380991 -10.321892  37.868559  30.534775  14.551351
#
#     RI     DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  2.0  25.130244  8.168000  0.182537  49.262195  105.593185  [-68, -67)
# 1  2.0  25.423265  5.242245  0.304898  49.159388  105.514980  [-68, -67)
# 2  2.0  24.942252  6.296757  0.030000  49.259640  104.383252  [-68, -67)
#
#
# [-67, -66): 5 samples
#    loc_id  lat_bin  lon_bin  \
# 0      52   167189   446975
# 1      55   167189   446978
# 2      59   167190   446975
# 3      67   167203   446974
# 4      69   167204   446974
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     12.0   -36.38
# 1  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     37.0   -36.14
# 2  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     38.0   -36.87
# 3  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...      8.0   -36.17
# 4  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     13.0   -40.99
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -33.33   -40.92 -66.616066 -10.342131  35.127049  39.741967  12.639344
# 1   -30.68   -43.90 -66.875350 -10.347484  30.251975  39.387643  13.830446
# 2   -29.39   -44.29 -66.108740 -10.333701  35.810945  39.835748  12.671260
# 3   -29.23   -44.76 -66.768000 -10.347467  29.473733  34.184800  14.027867
# 4   -35.91   -45.20 -66.866573 -10.334225  34.230610  34.132676  14.311831
#
#     RI     DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  2.0  23.902623  8.883770  0.200328  49.230000  100.115131  [-67, -66)
# 1  2.0  23.117675  8.537707  0.359013  49.442420   96.999261  [-67, -66)
# 2  2.0  24.740079  8.043071  0.358661  49.315591  104.163929  [-67, -66)
# 3  2.0  25.133733  7.581467  0.105733  49.330800  105.912147  [-67, -66)
# 4  2.0  24.899390  7.484883  0.104883  49.308498  104.566263  [-67, -66)
#
#
# [-66, -65): 5 samples
#    loc_id  lat_bin  lon_bin  \
# 0      53   167189   446976
# 1      54   167189   446977
# 2      60   167190   446976
# 3      63   167200   446975
# 4     106   167210   446996
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_02_Huam415-1, 251022_03_Huam415-1, 251...     25.0   -34.98
# 1  [251022_02_Huam415-1, 251022_03_Huam415-1, 251...     32.0   -36.80
# 2  [251022_01_Huam415-1, 251022_02_Huam415-1, 251...     25.0   -33.52
# 3  [251022_27_Huam345-5, 251024_01_Huam345-5, 251...      6.0   -31.36
# 4  [251023_03_Namsan, 251023_06_Namsan, 251023_07...      6.0   -21.35
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -28.86   -44.75 -65.381457 -10.336432  34.797638  39.670452  14.538141
# 1   -31.18   -43.11 -65.763911 -10.347269  31.941402  39.280111  14.090590
# 2   -27.47   -42.05 -65.137167 -10.317083  35.779417  39.822167  13.743667
# 3   -25.95   -38.04 -65.310000 -10.388226  27.208710  34.329355  14.280968
# 4   -15.92   -26.37 -65.512018 -10.331930  36.401754  30.553596  14.699737
#
#     RI     DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  2.0  25.228191  7.323015  0.302714  49.260201  106.158960  [-66, -65)
# 1  2.0  24.446421  8.062952  0.287306  49.311697  102.761786  [-66, -65)
# 2  2.0  25.352667  7.304833  0.876083  49.296083  106.926375  [-66, -65)
# 3  2.0  24.666935  8.526129  0.274032  49.273065  103.778774  [-66, -65)
# 4  2.0  25.617895  5.607193  0.302368  49.235789  107.392158  [-66, -65)
#
#
# [-65, -64): 1 samples
#    loc_id  lat_bin  lon_bin  \
# 0     116   167211   446996
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251023_03_Namsan, 251023_06_Namsan, 251023_08...      2.0   -14.38
#
#    uhd_max  uhd_min       RSRP       RSRQ  SINR   SINR_TRS        CQI   RI  \
# 0   -10.98   -17.79 -64.116615 -10.339231  35.7  30.384769  14.394923  2.0
#
#       DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  24.122308  7.528462  0.214615  49.124615  100.535892  [-65, -64)
#
#
# [-64, -63): 2 samples
#    loc_id  lat_bin  lon_bin  \
# 0      64   167200   446976
# 1      66   167202   446975
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251024_01_Huam345-5, 251024_02_Huam345-5, 251...      3.0   -33.91
# 1  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     13.0   -42.40
#
#    uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI  \
# 0   -31.08   -36.17 -63.279268 -10.348049  29.182927  34.698537  14.122195
# 1   -27.86   -47.62 -63.538693 -10.341867  30.688373  34.367733  14.610080
#
#     RI     DL_MCS   DL_BLER   UL_BLER     DL_RB     DL_Tput    RSRP_bin
# 0  2.0  24.826829  8.153659  0.538049  49.29878  104.413195  [-64, -63)
# 1  2.0  25.788560  6.315093  0.418453  49.41416  108.890035  [-64, -63)
#
#
# [-63, -62): 1 samples
#    loc_id  lat_bin  lon_bin  \
# 0      65   167201   446975
#
#                                            test_list  uhd_cnt  uhd_avg  \
# 0  [251022_26_Huam345-5, 251022_27_Huam345-5, 251...     12.0   -32.27
#
#    uhd_max  uhd_min       RSRP       RSRQ     SINR   SINR_TRS        CQI   RI  \
# 0   -26.41   -42.15 -62.938861 -10.351944  31.6285  34.543556  14.660917  2.0
#
#       DL_MCS   DL_BLER   UL_BLER      DL_RB    DL_Tput    RSRP_bin
# 0  25.772139  6.022194  0.644333  49.405778  108.78385  [-63, -62)
#
#
# [-54, -53): 1 samples
#    loc_id  lat_bin  lon_bin                             test_list  uhd_cnt  \
# 0     115   167211   446995  [251023_03_Namsan, 251023_08_Namsan]      3.0
#
#    uhd_avg  uhd_max  uhd_min       RSRP       RSRQ       SINR   SINR_TRS  \
# 0    -21.9   -19.39   -24.56 -53.197385 -10.328308  40.382769  30.519846
#
#          CQI   RI     DL_MCS   DL_BLER   UL_BLER      DL_RB   DL_Tput  \
# 0  14.937385  2.0  26.055846  3.520615  0.048462  49.402769  109.3672
#
#      RSRP_bin
# 0  [-54, -53)
#
#
# [-53, -52): 1 samples
#    loc_id  lat_bin  lon_bin           test_list  uhd_cnt  uhd_avg  uhd_max  \
# 0     128   167212   446995  [251023_08_Namsan]      3.0   -19.95   -16.97
#
#    uhd_min       RSRP       RSRQ       SINR   SINR_TRS        CQI   RI  \
# 0   -24.79 -52.720385 -10.329615  41.375769  30.552308  14.980769  2.0
#
#       DL_MCS   DL_BLER   UL_BLER      DL_RB     DL_Tput    RSRP_bin
# 0  26.338846  3.096923  0.058462  49.446538  110.849462  [-53, -52)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------------------------------------
# 1️⃣ uhd_max 유효한 행만 추출 + 복사
# ------------------------------------------------------------
df_uhd = df_pair.dropna(subset=["uhd_max"]).copy()

# ------------------------------------------------------------
# 2️⃣ uhd_group 생성 (-32 기준)
# ------------------------------------------------------------
df_uhd["uhd_group"] = np.where(df_uhd["uhd_max"] >= -32, "≥-32", "<-32")

# ------------------------------------------------------------
# 3️⃣ 필요한 컬럼만 추출
# ------------------------------------------------------------
cols = [
    "RSRP_mean_n26", "RSRP_mean_n28",
    "DL_Tput_mean_n26", "DL_Tput_mean_n28",
    "uhd_group"
]
df_sub = df_uhd[cols].copy()

# ------------------------------------------------------------
# 4️⃣ n26 / n28 데이터를 세로로 병합 (melt 구조)
# ------------------------------------------------------------
df_melt = pd.DataFrame({
    "RSRP": pd.concat([df_sub["RSRP_mean_n26"], df_sub["RSRP_mean_n28"]], ignore_index=True),
    "DL_Tput": pd.concat([df_sub["DL_Tput_mean_n26"], df_sub["DL_Tput_mean_n28"]], ignore_index=True),
    "Band": ["n26"] * len(df_sub) + ["n28"] * len(df_sub),
    "uhd_group": list(df_sub["uhd_group"]) + list(df_sub["uhd_group"])
})

# ------------------------------------------------------------
# 5️⃣ 산포도 시각화
# ------------------------------------------------------------
fig, axes = plt.subplots(2, 1, figsize=(10, 10), sharex=True, sharey=True)

color_map = {
    "≥-32": "#C00000",  # 빨강 (UHD 강)
    "<-32": "#0070C0"   # 파랑 (UHD 약)
}

for i, band in enumerate(["n26", "n28"]):
    ax = axes[i]
    for uhd_group, df_sub in df_melt[df_melt["Band"] == band].groupby("uhd_group"):
        ax.scatter(
            df_sub["RSRP"],
            df_sub["DL_Tput"],
            s=25,
            alpha=0.6,
            color=color_map[uhd_group],
            label=f"{uhd_group}"
        )

    ax.set_title(f"Band {band.upper()} — DL Throughput vs RSRP (Scatter)", fontsize=13, pad=8)
    ax.set_ylabel("DL Throughput [Mbps]", fontsize=11)
    ax.grid(True, linestyle="--", alpha=0.5)
    ax.legend(title="UHD Power", fontsize=9)
    ax.invert_xaxis()  # ✅ x축 반전 (RSRP 오른쪽이 강한 신호)

axes[-1].set_xlabel("RSRP [dBm]", fontsize=12)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

bins = np.arange(df["RSRP"].min(), df["RSRP"].max() + 1, 1)
df["RSRP_bin"] = pd.cut(df["RSRP"], bins=bins, right=False)
df["RSRP_bin_center"] = df["RSRP_bin"].apply(lambda x: (x.left + x.right) / 2)

df_grouped = (
    df.groupby(["Band", "RSRP_bin_center"], observed=True)["DL_Tput"]
      .mean()
      .reset_index()
)

fig, ax = plt.subplots(figsize=(14, 6))
for band, color in zip(["n26", "n28"], ["blue", "red"]):
    df_sub = df_grouped[df_grouped["Band"] == band]
    ax.plot(
        df_sub["RSRP_bin_center"], df_sub["DL_Tput"],
        marker="o", markersize=3, label=band, color=color, linewidth=1, alpha=0.85
    )
ax.set_xlim(-120, -40)
ax.set_xlabel("RSRP [dBm]")
ax.set_ylabel("DL Throughput [Mbps]")
ax.legend()

ax.grid(True, which='major', linestyle='-', linewidth=0.6, alpha=0.6)
ax.minorticks_on()
ax.grid(True, which='minor', linestyle=':', linewidth=0.4, alpha=0.4)

ax.invert_xaxis()

plt.tight_layout()
plt.show()

# %%
df_pair = _common.grid_kpi(df, grid_size=grid_size)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# ----------------------------
# 거리 구간 정의 (200m step)
# ----------------------------
bins = [0, 200, 400, 600, 800, 1000, np.inf]
labels = [
    "0–200 m", "200–400 m", "400–600 m",
    "600–800 m", "800–1000 m", "1000 m+"
]
df_pair["distance_bin"] = pd.cut(df_pair["distance"], bins=bins, labels=labels, right=False)

# ----------------------------
# 색상 로직
# ----------------------------
source_order = labels
base_sources = [s for s in source_order if s not in ['clean']]
num_base = len(base_sources)

cmap = matplotlib.colormaps.get_cmap("tab20b")
base_colors = [cmap(i / 20) for i in np.linspace(4, 19, num=num_base)]

# ----------------------------
# 그래프 그리기
# ----------------------------
plt.figure(figsize=(15,7))
plt.title("Average DL Throughput vs RSRP (n28)", fontsize=13)
plt.xlabel("RSRP_n28 (dBm)")
plt.ylabel("Average DL_Tput_n28 (Mbps)")
plt.grid(True, linestyle="--", alpha=0.4)

# 거리 순서를 역순으로 (멀리 → 가까이)
for label, color in zip(reversed(base_sources), reversed(base_colors)):
    df_sub = df_pair[df_pair["distance_bin"] == label].copy()
    if df_sub.empty:
        continue

    # 1 dB 단위 binning
    df_sub.loc[:, "RSRP_bin"] = df_sub["RSRP_n28"].astype(int)

    # 평균 계산
    df_binned = (
        df_sub.groupby("RSRP_bin", observed=True)["DL_Tput_n28"]
              .mean()
              .reset_index()
              .sort_values("RSRP_bin")
    )

    plt.plot(
        df_binned["RSRP_bin"],
        df_binned["DL_Tput_n28"],
        label=label,
        color=color,
        linewidth=1,
        marker='o',
        markersize=3,
    )

# ----------------------------
# 축/범례/레이아웃 설정
# ----------------------------
plt.gca().invert_xaxis()
plt.xlim(-60, -120)
# plt.ylim(0, 70)


# ✅ 범례를 그래프 안쪽에, 역순으로 배치
handles, legend_labels = plt.gca().get_legend_handles_labels()
plt.legend(
    handles[::-1],
    legend_labels[::-1],
    title="Distance",
    fontsize=11,
    title_fontsize=11,
    loc="upper right",
    frameon=True,
    framealpha=0.9,
    facecolor="white",
    edgecolor="gray"
)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# ----------------------------
# uhd_max 구간 정의 (3 dB step)
# ----------------------------
uhd_min, uhd_max = -38, df_pair["uhd_max"].max()
uhd_bins = np.arange(uhd_min, np.ceil(uhd_max) + 3, 3)
uhd_labels = [f"{uhd_bins[i]}~{uhd_bins[i+1]} dB" for i in range(len(uhd_bins)-1)]

# -38 이하 제외 후 구간화
df_pair_filtered = df_pair[df_pair["uhd_max"] > -38].copy()
df_pair_filtered["uhd_bin"] = pd.cut(df_pair_filtered["uhd_max"], bins=uhd_bins, labels=uhd_labels, right=False)

# ----------------------------
# 색상 로직
# ----------------------------
source_order = uhd_labels
base_sources = [s for s in source_order if s not in ['clean']]
num_base = len(base_sources)

cmap = matplotlib.colormaps.get_cmap("tab20b")
base_colors = [cmap(i / 20) for i in np.linspace(4, 19, num=num_base)]

# ----------------------------
# 그래프 그리기
# ----------------------------
plt.figure(figsize=(15,7))
plt.title("Average DL Throughput vs RSRP (n28) by UHD_MAX bins", fontsize=13)
plt.xlabel("RSRP_n28 (dBm)")
plt.ylabel("Average DL_Tput_n28 (Mbps)")
plt.grid(True, linestyle="--", alpha=0.4)

# 구간 역순으로 (큰 UHD → 작은 UHD)
for label, color in zip(reversed(base_sources), reversed(base_colors)):
    df_sub = df_pair_filtered[df_pair_filtered["uhd_bin"] == label].copy()
    if df_sub.empty:
        continue

    # 1 dB 단위 binning
    df_sub.loc[:, "RSRP_bin"] = df_sub["RSRP_n28"].astype(int)

    # 평균 계산
    df_binned = (
        df_sub.groupby("RSRP_bin", observed=True)["DL_Tput_n28"]
              .mean()
              .reset_index()
              .sort_values("RSRP_bin")
    )

    plt.plot(
        df_binned["RSRP_bin"],
        df_binned["DL_Tput_n28"],
        label=label,
        color=color,
        linewidth=1,
        marker='o',
        markersize=3,
    )

# ----------------------------
# 축/범례/레이아웃 설정
# ----------------------------
plt.gca().invert_xaxis()
plt.xlim(-60, -120)
# plt.ylim(0,80)

handles, legend_labels = plt.gca().get_legend_handles_labels()
plt.legend(
    handles[::-1],
    legend_labels[::-1],
    title="UHD_MAX (dB)",
    fontsize=11,
    title_fontsize=11,
    loc="upper right",
    frameon=True,
    framealpha=0.9,
    facecolor="white",
    edgecolor="gray"
)

plt.tight_layout()
plt.show()
