# %%
# log파일 추가 시 한번만 실행
import _common
_common.read_logs()
# Out:
# Reading logs/Huam415-1/251016_SM-S938N_TEST06_n-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST16-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST31_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST24-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST17-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST02_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST09_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST30_-M2_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST02_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST13_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST13-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST20-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST14_-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST05_n-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST21-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST12-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST11-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST22-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST03_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST04_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST10_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST23-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST18-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST19-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST33_-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST01_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST01_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST34-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST14-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST35_-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST03_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST32_-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST04_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST15-M2_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST01_N26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST13_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST14_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST13-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST20-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST05_n-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST21-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST12-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST30_-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST04_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST03_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST09_-M2_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST04_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST03_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST16-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST06_n-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST31_-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST01_n28-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST24-M1_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST17-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST34-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST14-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST35_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST32_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST15-M1_Fav.xlsx
# Reading logs/Huam415-1/251017_SM-S938N_TEST02_N28-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST18-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST33_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST19-M1_Fav.xlsx
# Reading logs/Huam415-1/251016_SM-S938N_TEST02_n26-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST11-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST22-M1_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Huam415-1/251022_SM-S938N_TEST10_-M2_Fav.xlsx
# Reading logs/Huam415-1/251024_SM-S938N_TEST23-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST10_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST11_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST17_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST08_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST16_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST09_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST18_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST14_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST15_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST12_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST06_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST07_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST13_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST14_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST12_M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST13_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST08_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST16_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST09_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST18_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST14_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST17_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST10_M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST11_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST12_M1_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST13_M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST06_M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Namsan/251021_SM-S938N_TEST07_M1_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST13_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST14_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST15_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST12_-M2_Fav.xlsx
# Reading logs/Namsan/251023_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST27_STATIC_-M1_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST26_STATIC_-M1_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST25_STATIC_-M1_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST25_STATIC_-M2_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST27_STATIC_-M2_Fav.xlsx
# Reading logs/Fixed/251024_SM-S938N_TEST26_STATIC_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST24_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST23_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST28_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST38_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST11_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST26_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST21_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST19_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST02-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST04_M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST17_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST10_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST40_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST03-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST05_M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST29_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST20_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST07-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST39_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST27_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST10_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST22_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST25_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST32_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST06-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST18_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST11_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST16_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST12_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST15_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST09_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST10-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST31_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST28_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST05-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST21_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST03_M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST26_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST04-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST23_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST24_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST17_TRACE_-M2_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST02_M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST16_-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST14_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST13_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST01-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST25_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST22_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST09-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST29_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST30_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST27_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST08-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST20_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST09_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST04_-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST03_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST03_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST04_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST18_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST11_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST16_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST29_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST20_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST07-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST39_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST10_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST27_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST22_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST25_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST32_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST06-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST19_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST02-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST17_-M2_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST04_M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST10_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST03-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST02_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST40_-M1_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST05_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST05_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST02_-M2_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST05_M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST24_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST23_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST28_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST38_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST26_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST11_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST21_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST25_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST22_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST09-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST29_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST07_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST30_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST27_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST08-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST20_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST09_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST06_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST01_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST08_-M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST16_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST01_-M2_Fav.xlsx
# Reading logs/Huam345-5/251023_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST14_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST13_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST01-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST31_-M1_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST06_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST05-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST28_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST03_M2_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST21_-M2_Fav.xlsx
# Reading logs/Huam345-5/251020_SM-S938N_TEST08_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST26_-M2_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST04-M2_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST23_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST24_-M1_Fav.xlsx
# Reading logs/Huam345-5/251022_SM-S938N_TEST17_TRACE_-M1_Fav.xlsx
# Reading logs/Huam345-5/251021_SM-S938N_TEST02_M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST12_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST15_-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST07_-M1_Fav.xlsx
# Reading logs/Huam345-5/251024_SM-S938N_TEST10-M1_Fav.xlsx
# Reading logs/Huam345-5/251027_SM-S938N_TEST09_-M2_Fav.xlsx
# ✅ Saved: logs/SM-S938N_All.xlsx

# %%
import os, _common, _map, _plot, _trend
df = _common.analyze_kpi(
    fname = os.path.join("logs",f"SM-S938N_All.xlsx"),
    date_list = [
        # "251016",
        # "251017",
        # "251020",
        # "251021",
        "251022", # pdcch dynamic 적용
        "251023",
        "251024",
        "251027",
    ],
)
df_all = df[df["route"]!="Fixed"].copy()

out_dir = os.path.join("results", "All")
os.makedirs(out_dir, exist_ok=True)

_map.map_pct(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
_map.map_db(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
_map.map_coverage(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)
_trend.kpi_each_test(df=df_all, out_dir=out_dir, grid_size=25, rb_min=48, sample_min=10)

site_list = [
    'Huam415-1',
    'Huam345-5',
    'Namsan',
    'Fixed',
]
for site in site_list:
    df_site = df[df["route"]==site].copy()
    
    out_dir = os.path.join("results", site)
    os.makedirs(out_dir, exist_ok=True)
    
    _map.map_pct(df=df_site, out_dir=out_dir, grid_size=5, rb_min=48, sample_min=2)
    _trend.rb_each_test(df=df_site, out_dir=out_dir, rb_min=0)
# Out:
# Reading logs/SM-S938N_All.xlsx
# ✅ Read Complete : 89661 lines
# ✅ Saved: results/All/map_25m_DL_Tput_ratio.html (rows=206)
# ✅ Saved: results/All/map_25m_RSRP_diff.html (rows=206)
# ✅ Saved: results/All/map_25m_RSRP_n28.html (rows=206)
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_01_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_02_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_03_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_04_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_05_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_06_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_07_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_08_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_09_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_10_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_13_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_14_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_16_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_17_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_20_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_21_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_22_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_23_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_24_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_25_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_26_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_27_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_28_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_29_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_30_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_31_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_32_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_33_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_34_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_35_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_38_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_39_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251022/251022_40_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_01_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_01_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_02_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_02_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_03_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_03_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_04_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_04_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_05_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_05_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_06_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_06_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_07_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_08_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_12_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_13_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_14_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_15_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_16_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_17_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251023/251023_18_Namsan.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_01_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_02_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_03_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_04_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_05_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_06_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_07_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_08_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_09_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_10_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_11_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_12_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_13_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_14_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_15_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_16_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_17_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_18_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_19_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_20_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_21_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_22_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_23_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251024/251024_24_Huam415-1.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_01_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_02_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_03_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_04_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_05_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_06_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_07_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_08_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_09_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_10_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_11_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_12_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_13_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_14_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_15_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_16_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_17_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_18_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_19_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_20_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_21_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_22_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_23_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_24_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_25_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_26_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_27_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_28_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_29_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_30_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_31_Huam345-5.html
# Saved HTML: results/All/plot_kpi_each_test/251027/251027_32_Huam345-5.html
# ✅ Saved: results/Huam415-1/map_5m_DL_Tput_ratio.html (rows=576)
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_01_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_02_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_03_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_04_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_05_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_06_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_07_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_08_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_09_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_10_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_13_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_14_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_30_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_31_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_32_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_33_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_34_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251022/251022_35_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_11_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_12_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_13_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_14_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_15_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_16_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_17_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_18_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_19_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_20_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_21_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_22_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_23_Huam415-1.html
# Saved HTML: results/Huam415-1/plot_kpi_each_test/251024/251024_24_Huam415-1.html
# Saved: results/Huam415-1/plot_RB_each_test/251022.png
# Saved: results/Huam415-1/plot_RB_each_test/251024.png
# ✅ Saved: results/Huam345-5/map_5m_DL_Tput_ratio.html (rows=888)
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_16_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_17_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_20_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_21_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_22_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_23_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_24_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_25_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_26_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_27_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_28_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_29_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_38_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_39_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251022/251022_40_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251023/251023_01_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251023/251023_02_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251023/251023_03_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251023/251023_04_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251023/251023_05_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251023/251023_06_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_01_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_02_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_03_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_04_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_05_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_06_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_07_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_08_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_09_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251024/251024_10_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_01_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_02_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_03_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_04_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_05_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_06_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_07_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_08_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_09_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_10_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_11_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_12_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_13_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_14_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_15_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_16_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_17_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_18_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_19_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_20_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_21_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_22_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_23_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_24_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_25_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_26_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_27_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_28_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_29_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_30_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_31_Huam345-5.html
# Saved HTML: results/Huam345-5/plot_kpi_each_test/251027/251027_32_Huam345-5.html
# Saved: results/Huam345-5/plot_RB_each_test/251022.png
# Saved: results/Huam345-5/plot_RB_each_test/251023.png
# Saved: results/Huam345-5/plot_RB_each_test/251024.png
# Saved: results/Huam345-5/plot_RB_each_test/251027.png
# ✅ Saved: results/Namsan/map_5m_DL_Tput_ratio.html (rows=300)
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_01_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_02_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_03_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_04_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_05_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_06_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_07_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_08_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_12_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_13_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_14_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_15_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_16_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_17_Namsan.html
# Saved HTML: results/Namsan/plot_kpi_each_test/251023/251023_18_Namsan.html
# Saved: results/Namsan/plot_RB_each_test/251023.png
# ✅ Saved: results/Fixed/map_5m_DL_Tput_ratio.html (rows=5)
# Saved HTML: results/Fixed/plot_kpi_each_test/251024/251024_25_Fixed.html
# Saved HTML: results/Fixed/plot_kpi_each_test/251024/251024_26_Fixed.html
# Saved HTML: results/Fixed/plot_kpi_each_test/251024/251024_27_Fixed.html
# Saved: results/Fixed/plot_RB_each_test/251024.png

# %%
# _plot.plot_kpi(df=df, grid_size=1, out_dir=out_dir, title=title)
# _plot.plot_tput_vs_sinr(df=df, grid_size=1, out_dir=out_dir, title=title)

# %%
import os, _common, _map, _plot, _trend

df = _common.analyze_kpi(
    fname = os.path.join("logs",f"SM-S938N_All.xlsx"),
    date_list = [
        # "251016",
        # "251017",
        # "251020",
        # "251021",
        "251022", # pdcch dynamic 적용
        "251023",
    ],
)
df = df[df["DL_RB"]>48]
display(df)
# Out:
# Reading logs/SM-S938N_All.xlsx
# ✅ Read Complete : 62029 lines
#                      TIME    date      route              test_no        Lon  \
# 0     2025-10-22 14:51:48  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 1     2025-10-22 14:51:48  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 2     2025-10-22 14:51:49  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 3     2025-10-22 14:51:49  251022  Huam415-1  251022_01_Huam415-1  126.98240
# 4     2025-10-22 14:51:50  251022  Huam415-1  251022_01_Huam415-1  126.98242
# ...                   ...     ...        ...                  ...        ...
# 34690 2025-10-23 17:41:49  251023     Namsan     251023_18_Namsan  126.98776
# 34691 2025-10-23 17:41:50  251023     Namsan     251023_18_Namsan  126.98775
# 34692 2025-10-23 17:41:50  251023     Namsan     251023_18_Namsan  126.98775
# 34693 2025-10-23 17:41:51  251023     Namsan     251023_18_Namsan  126.98775
# 34694 2025-10-23 17:41:51  251023     Namsan     251023_18_Namsan  126.98775
#
#             Lat    Distance Band   RSRP   RSRQ  ...  SINR_TRS    CQI   RI  \
# 0      37.54704  654.025416  n28 -63.39 -10.34  ...     40.34  13.33  2.0
# 1      37.54704  654.025416  n26 -59.96 -10.33  ...     33.63  14.00  2.0
# 2      37.54704  654.025416  n28 -65.35 -10.38  ...     40.46  13.25  2.0
# 3      37.54704  654.025416  n26 -63.92 -10.32  ...     33.53  14.00  2.0
# 4      37.54703  653.558332  n28 -64.21 -10.33  ...     40.50  13.00  2.0
# ...         ...         ...  ...    ...    ...  ...       ...    ...  ...
# 34690  37.55178   67.287143  n28 -70.31 -10.34  ...     30.56  14.67  2.0
# 34691  37.55179   68.296113  n28 -71.30 -10.35  ...     30.77  14.00  2.0
# 34692  37.55179   68.296113  n26 -62.13 -10.32  ...     28.08  15.00  2.0
# 34693  37.55180   69.402358  n28 -63.72 -10.35  ...     30.52  14.50  2.0
# 34694  37.55180   69.402358  n26 -64.78 -10.33  ...     27.99  15.00  2.0
#
#        DL_MCS  DL_BLER  UL_BLER  DL_RB  DL_Tput  DL_Tput_per_RB  \
# 0       25.52     5.71      0.0  49.52  107.088        2.162520
# 1       19.19     8.78      0.0  49.84   79.905        1.603230
# 2       20.38     9.83      0.0  49.73   85.903        1.727388
# 3       21.69    10.72      0.0  49.78   91.579        1.839675
# 4       23.44     7.50      0.0  49.44   98.432        1.990939
# ...       ...      ...      ...    ...      ...             ...
# 34690   25.80     3.37      0.0  49.70  109.460        2.202414
# 34691   25.81     5.43      0.0  49.32  108.698        2.203933
# 34692   26.31     5.21      0.0  49.77  111.924        2.248825
# 34693   25.60     6.24      0.0  49.11  108.183        2.202871
# 34694   26.43     5.69      0.0  49.75  112.497        2.261246
#
#        DL_Tput_full_RB
# 0           112.451050
# 1            83.367978
# 2            89.824171
# 3            95.663078
# 4           103.528803
# ...                ...
# 34690       114.525553
# 34691       114.604542
# 34692       116.938879
# 34693       114.549297
# 34694       117.584804
#
# [33082 rows x 22 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

bins = np.arange(df["RSRP"].min(), df["RSRP"].max() + 1, 1)
df["RSRP_bin"] = pd.cut(df["RSRP"], bins=bins, right=False)
df["RSRP_bin_center"] = df["RSRP_bin"].apply(lambda x: (x.left + x.right) / 2)

df_grouped = (
    df.groupby(["Band", "RSRP_bin_center"], observed=True)["DL_Tput"]
      .mean()
      .reset_index()
)

fig, ax = plt.subplots(figsize=(14, 6))
for band, color in zip(["n26", "n28"], ["blue", "red"]):
    df_sub = df_grouped[df_grouped["Band"] == band]
    ax.plot(
        df_sub["RSRP_bin_center"], df_sub["DL_Tput"],
        marker="o", markersize=3, label=band, color=color, linewidth=1, alpha=0.85
    )
ax.set_xlim(-120, -40)
ax.set_xlabel("RSRP [dBm]")
ax.set_ylabel("DL Throughput [Mbps]")
ax.legend()

ax.grid(True, which='major', linestyle='-', linewidth=0.6, alpha=0.6)
ax.minorticks_on()
ax.grid(True, which='minor', linestyle=':', linewidth=0.4, alpha=0.4)

ax.invert_xaxis()

plt.tight_layout()
plt.show()

# %%
df_pair = _common.grid_kpi(df, grid_size=grid_size)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# ----------------------------
# 거리 구간 정의 (200m step)
# ----------------------------
bins = [0, 200, 400, 600, 800, 1000, np.inf]
labels = [
    "0–200 m", "200–400 m", "400–600 m",
    "600–800 m", "800–1000 m", "1000 m+"
]
df_pair["distance_bin"] = pd.cut(df_pair["distance"], bins=bins, labels=labels, right=False)

# ----------------------------
# 색상 로직
# ----------------------------
source_order = labels
base_sources = [s for s in source_order if s not in ['clean']]
num_base = len(base_sources)

cmap = matplotlib.colormaps.get_cmap("tab20b")
base_colors = [cmap(i / 20) for i in np.linspace(4, 19, num=num_base)]

# ----------------------------
# 그래프 그리기
# ----------------------------
plt.figure(figsize=(15,7))
plt.title("Average DL Throughput vs RSRP (n28)", fontsize=13)
plt.xlabel("RSRP_n28 (dBm)")
plt.ylabel("Average DL_Tput_n28 (Mbps)")
plt.grid(True, linestyle="--", alpha=0.4)

# 거리 순서를 역순으로 (멀리 → 가까이)
for label, color in zip(reversed(base_sources), reversed(base_colors)):
    df_sub = df_pair[df_pair["distance_bin"] == label].copy()
    if df_sub.empty:
        continue

    # 1 dB 단위 binning
    df_sub.loc[:, "RSRP_bin"] = df_sub["RSRP_n28"].astype(int)

    # 평균 계산
    df_binned = (
        df_sub.groupby("RSRP_bin", observed=True)["DL_Tput_n28"]
              .mean()
              .reset_index()
              .sort_values("RSRP_bin")
    )

    plt.plot(
        df_binned["RSRP_bin"],
        df_binned["DL_Tput_n28"],
        label=label,
        color=color,
        linewidth=1,
        marker='o',
        markersize=3,
    )

# ----------------------------
# 축/범례/레이아웃 설정
# ----------------------------
plt.gca().invert_xaxis()
plt.xlim(-60, -120)
# plt.ylim(0, 70)


# ✅ 범례를 그래프 안쪽에, 역순으로 배치
handles, legend_labels = plt.gca().get_legend_handles_labels()
plt.legend(
    handles[::-1],
    legend_labels[::-1],
    title="Distance",
    fontsize=11,
    title_fontsize=11,
    loc="upper right",
    frameon=True,
    framealpha=0.9,
    facecolor="white",
    edgecolor="gray"
)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# ----------------------------
# uhd_max 구간 정의 (3 dB step)
# ----------------------------
uhd_min, uhd_max = -38, df_pair["uhd_max"].max()
uhd_bins = np.arange(uhd_min, np.ceil(uhd_max) + 3, 3)
uhd_labels = [f"{uhd_bins[i]}~{uhd_bins[i+1]} dB" for i in range(len(uhd_bins)-1)]

# -38 이하 제외 후 구간화
df_pair_filtered = df_pair[df_pair["uhd_max"] > -38].copy()
df_pair_filtered["uhd_bin"] = pd.cut(df_pair_filtered["uhd_max"], bins=uhd_bins, labels=uhd_labels, right=False)

# ----------------------------
# 색상 로직
# ----------------------------
source_order = uhd_labels
base_sources = [s for s in source_order if s not in ['clean']]
num_base = len(base_sources)

cmap = matplotlib.colormaps.get_cmap("tab20b")
base_colors = [cmap(i / 20) for i in np.linspace(4, 19, num=num_base)]

# ----------------------------
# 그래프 그리기
# ----------------------------
plt.figure(figsize=(15,7))
plt.title("Average DL Throughput vs RSRP (n28) by UHD_MAX bins", fontsize=13)
plt.xlabel("RSRP_n28 (dBm)")
plt.ylabel("Average DL_Tput_n28 (Mbps)")
plt.grid(True, linestyle="--", alpha=0.4)

# 구간 역순으로 (큰 UHD → 작은 UHD)
for label, color in zip(reversed(base_sources), reversed(base_colors)):
    df_sub = df_pair_filtered[df_pair_filtered["uhd_bin"] == label].copy()
    if df_sub.empty:
        continue

    # 1 dB 단위 binning
    df_sub.loc[:, "RSRP_bin"] = df_sub["RSRP_n28"].astype(int)

    # 평균 계산
    df_binned = (
        df_sub.groupby("RSRP_bin", observed=True)["DL_Tput_n28"]
              .mean()
              .reset_index()
              .sort_values("RSRP_bin")
    )

    plt.plot(
        df_binned["RSRP_bin"],
        df_binned["DL_Tput_n28"],
        label=label,
        color=color,
        linewidth=1,
        marker='o',
        markersize=3,
    )

# ----------------------------
# 축/범례/레이아웃 설정
# ----------------------------
plt.gca().invert_xaxis()
plt.xlim(-60, -120)
# plt.ylim(0,80)

handles, legend_labels = plt.gca().get_legend_handles_labels()
plt.legend(
    handles[::-1],
    legend_labels[::-1],
    title="UHD_MAX (dB)",
    fontsize=11,
    title_fontsize=11,
    loc="upper right",
    frameon=True,
    framealpha=0.9,
    facecolor="white",
    edgecolor="gray"
)

plt.tight_layout()
plt.show()
